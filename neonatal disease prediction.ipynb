# %%
#Importing pandas.Using it for data analysis and data manipulation
import pandas as pd

# %%
#Reading the dataset
df = pd.read_csv(r"Processed_Neonatalmodels.csv",encoding= 'unicode_escape')

# %%
#Checking head and examining
df.head(10)
# Out:
#    Grunting   WBC  CRP  RR  BC  weight  GA  SpO2  ICSCR  resuscitate  APGARS  \
# 0         1  4520    1  32   0     2.0   2     1      0            0       0
# 1         1  4520    0  66   0     2.0   2     1      0            0       0
# 2         1  4520    1  80   0     2.0   2     1      0            0       0
# 3         1  4520    1  69   1     2.0   2     1      0            0       0
# 4         1  4520    0  38   1     2.0   2     1      0            0       0
# 5         1  4520    0  27   1     2.0   1     1      0            0       1
# 6         1  4520    0  22   1     2.0   2     1      0            1       1
# 7         1  7500    0  65   1     2.0   1     1      0            0       1
# 8         1  9000    0  23   0     2.0   2     1      0            0       1
# 9         1  9500    1  63   0     2.0   2     1      0            0       1
#
#    LLVW  Class
# 0     2      3
# 1     2      3
# 2     2      3
# 3     2      3
# 4     2      3
# 5     2      3
# 6     2      3
# 7     2      3
# 8     2      3
# 9     2      3

# %%
#Mean,count, and standard deviation is checked
df.describe()
# Out:
#           Grunting           WBC          CRP           RR           BC  \
# count  2298.000000   2298.000000  2298.000000  2298.000000  2298.000000
# mean      0.586597  10589.499565     0.524369    50.241079     0.479547
# std       0.492551   5853.253471     0.499514    18.971950     0.499690
# min       0.000000   2600.000000     0.000000    21.000000     0.000000
# 25%       0.000000   4520.000000     0.000000    28.000000     0.000000
# 50%       1.000000   9500.000000     1.000000    61.000000     0.000000
# 75%       1.000000  14600.000000     1.000000    66.000000     1.000000
# max       1.000000  31500.000000     1.000000    80.000000     1.000000
#
#             weight           GA         SpO2        ICSCR  resuscitate  \
# count  2298.000000  2298.000000  2298.000000  2298.000000  2298.000000
# mean      3.233551     0.967363     0.559617     0.312010     0.287641
# std       0.643707     0.976554     0.496541     0.463415     0.452762
# min       2.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.800000     0.000000     0.000000     0.000000     0.000000
# 50%       3.200000     1.000000     1.000000     0.000000     0.000000
# 75%       3.700000     2.000000     1.000000     1.000000     1.000000
# max       4.500000     2.000000     1.000000     1.000000     1.000000
#
#             APGARS         LLVW        Class
# count  2298.000000  2298.000000  2298.000000
# mean      0.449086     2.279809     1.721497
# std       0.497509     0.655536     1.085736
# min       0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     1.000000
# 50%       0.000000     2.000000     2.000000
# 75%       1.000000     3.000000     3.000000
# max       1.000000     3.000000     3.000000

# %%
#Data types and non-null count is displayed for all features. We have balanced data set here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2298 entries, 0 to 2297
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Grunting     2298 non-null   int64
#  1   WBC          2298 non-null   int64
#  2   CRP          2298 non-null   int64
#  3   RR           2298 non-null   int64
#  4   BC           2298 non-null   int64
#  5   weight       2298 non-null   float64
#  6   GA           2298 non-null   int64
#  7   SpO2         2298 non-null   int64
#  8   ICSCR        2298 non-null   int64
#  9   resuscitate  2298 non-null   int64
#  10  APGARS       2298 non-null   int64
#  11  LLVW         2298 non-null   int64
#  12  Class        2298 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 233.5 KB

# %%
#Number of rows and columns
df.shape
# Out:
# (2298, 13)

# %%
#Column names
df.columns
# Out:
# Index(['Grunting', 'WBC', 'CRP', 'RR', 'BC', 'weight', 'GA', 'SpO2', 'ICSCR',
#        'resuscitate', 'APGARS', 'LLVW', 'Class'],
#       dtype='object')

# %%
#Checking if any feature has null values. We have balanced dataset here
df.isnull().any()
# Out:
# Grunting       False
# WBC            False
# CRP            False
# RR             False
# BC             False
# weight         False
# GA             False
# SpO2           False
# ICSCR          False
# resuscitate    False
# APGARS         False
# LLVW           False
# Class          False
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Count Plot
sns.countplot(x="Class", data=df)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
#Density Plot
df.plot(kind='density', subplots=True, layout=(8,2), sharex=False , figsize =(18,20))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
#Histogram
df.hist(figsize = (12,10),color='cyan')
# Out:
# array([[<AxesSubplot:title={'center':'Grunting'}>,
#         <AxesSubplot:title={'center':'WBC'}>,
#         <AxesSubplot:title={'center':'CRP'}>],
#        [<AxesSubplot:title={'center':'RR'}>,
#         <AxesSubplot:title={'center':'BC'}>,
#         <AxesSubplot:title={'center':'weight'}>],
#        [<AxesSubplot:title={'center':'GA'}>,
#         <AxesSubplot:title={'center':'SpO2'}>,
#         <AxesSubplot:title={'center':'ICSCR'}>],
#        [<AxesSubplot:title={'center':'resuscitate'}>,
#         <AxesSubplot:title={'center':'APGARS'}>,
#         <AxesSubplot:title={'center':'LLVW'}>]], dtype=object)

# %%
#Box plot
df.plot(kind='box', subplots=True, layout=(7,2), sharex=False,sharey=False ,figsize =(18,18),
        color='red')
# Out:
# Grunting          AxesSubplot(0.125,0.787927;0.352273x0.0920732)
# WBC            AxesSubplot(0.547727,0.787927;0.352273x0.0920732)
# CRP               AxesSubplot(0.125,0.677439;0.352273x0.0920732)
# RR             AxesSubplot(0.547727,0.677439;0.352273x0.0920732)
# BC                AxesSubplot(0.125,0.566951;0.352273x0.0920732)
# weight         AxesSubplot(0.547727,0.566951;0.352273x0.0920732)
# GA                AxesSubplot(0.125,0.456463;0.352273x0.0920732)
# SpO2           AxesSubplot(0.547727,0.456463;0.352273x0.0920732)
# ICSCR             AxesSubplot(0.125,0.345976;0.352273x0.0920732)
# resuscitate    AxesSubplot(0.547727,0.345976;0.352273x0.0920732)
# APGARS            AxesSubplot(0.125,0.235488;0.352273x0.0920732)
# LLVW           AxesSubplot(0.547727,0.235488;0.352273x0.0920732)
# dtype: object

# %%
#Correlation
correlation = df.corr()
correlation
# Out:
#              Grunting       WBC       CRP        RR        BC    weight  \
# Grunting     1.000000 -0.020509 -0.127134  0.015422  0.144284 -0.048092
# WBC         -0.020509  1.000000  0.212081  0.005526 -0.223378  0.031599
# CRP         -0.127134  0.212081  1.000000  0.012243 -0.716602  0.015224
# RR           0.015422  0.005526  0.012243  1.000000  0.003000  0.011653
# BC           0.144284 -0.223378 -0.716602  0.003000  1.000000 -0.022074
# weight      -0.048092  0.031599  0.015224  0.011653 -0.022074  1.000000
# GA           0.015382 -0.091467  0.039561 -0.049485 -0.036609  0.022108
# SpO2         0.033173 -0.205345 -0.014636 -0.042056  0.012812 -0.005856
# ICSCR       -0.024013  0.286914  0.161792  0.029668 -0.180175  0.040723
# resuscitate -0.017063  0.093047  0.116252 -0.055414 -0.103874 -0.010425
# APGARS      -0.032633  0.418449  0.195943  0.022149 -0.208206  0.023848
# LLVW        -0.029908  0.231046  0.150011  0.045576 -0.157292 -0.053247
#
#                    GA      SpO2     ICSCR  resuscitate    APGARS      LLVW
# Grunting     0.015382  0.033173 -0.024013    -0.017063 -0.032633 -0.029908
# WBC         -0.091467 -0.205345  0.286914     0.093047  0.418449  0.231046
# CRP          0.039561 -0.014636  0.161792     0.116252  0.195943  0.150011
# RR          -0.049485 -0.042056  0.029668    -0.055414  0.022149  0.045576
# BC          -0.036609  0.012812 -0.180175    -0.103874 -0.208206 -0.157292
# weight       0.022108 -0.005856  0.040723    -0.010425  0.023848 -0.053247
# GA           1.000000  0.427335 -0.426740     0.044873 -0.059426 -0.489652
# SpO2         0.427335  1.000000 -0.465888     0.046656 -0.136623 -0.366247
# ICSCR       -0.426740 -0.465888  1.000000    -0.189313  0.434316  0.535082
# resuscitate  0.044873  0.046656 -0.189313     1.000000 -0.374649 -0.133411
# APGARS      -0.059426 -0.136623  0.434316    -0.374649  1.000000  0.356729
# LLVW        -0.489652 -0.366247  0.535082    -0.133411  0.356729  1.000000

# %%
#KDE plot
x = df['GA']
sns.kdeplot(x, shade=True, color='g')
# Out:
# <AxesSubplot:xlabel='GA', ylabel='Density'>

# %%
#Heat map
plt.figure(figsize=(18,12))
plt.title('Correlation Heatmap plot')
a = sns.heatmap(correlation, square=True, annot=True)
a.set_xticklabels(a.get_xticklabels())
a.set_yticklabels(a.get_yticklabels())           
plt.show()

# %%
#Pair-Plot
feature = ['Grunting', 'WBC', 'CRP', 'RR', 'BC','weight' ]
sns.pairplot(df[feature], kind='scatter', diag_kind='hist')

# %%
categorical = []
continous= []

# %%
for column in df.columns:
    if len(df[column].unique()) <= 10:
        categorical.append(column)
    else:
        continous.append(column)

# %%
categorical.remove('Class')

# %%
categorical
# Out:
# ['Grunting',
#  'CRP',
#  'BC',
#  'GA',
#  'SpO2',
#  'ICSCR',
#  'resuscitate',
#  'APGARS',
#  'LLVW']

# %%
continous
# Out:
# ['WBC', 'RR', 'weight']

# %%
dataset = pd.get_dummies(df, columns = categorical)

# %%
cols = ['Grunting', 'WBC', 'CRP', 'RR', 'BC','weight','GA','SpO2','ICSCR','resuscitate','APGARS','LLVW']

# %%
X = df[cols]

# %%
y = dataset.Class

# %%
df.columns
# Out:
# Index(['Grunting', 'WBC', 'CRP', 'RR', 'BC', 'weight', 'GA', 'SpO2', 'ICSCR',
#        'resuscitate', 'APGARS', 'LLVW', 'Class'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['Grunting', 'WBC', 'CRP', 'RR', 'BC', 'weight', 'GA', 'SpO2', 'ICSCR',
#        'resuscitate', 'APGARS', 'LLVW'],
#       dtype='object')

# %%
#Splitting into Train and Test dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#Using this class to make my print statement look bold
class color:
    BOLD = '\033[1m'

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

accuracies = {}

logreg = make_pipeline(StandardScaler(), LogisticRegression())
logreg.fit(X_train, y_train)

accuracy = accuracy_score(y_test, logreg.predict(X_test))
accuracy_rounded = round(accuracy*100,2)
accuracies['Logistic Regression'] = accuracy_rounded

print(color.BOLD + "Accuracy of Logistic regression is ", accuracy_rounded,'%')
# Out:
# Accuracy of Logistic regression is  94.35 %

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 6)
knn.fit(X_train, y_train)

accuracy = accuracy_score(y_test, knn.predict(X_test))
accuracy_rounded = round(accuracy*100,2)

accuracies['K-Nearest Neighbors'] = accuracy_rounded

print(color.BOLD + "Accuracy of K-Nearest Neigbors is ", accuracy_rounded,'%')
# Out:
# Accuracy of K-Nearest Neigbors is  60.0 %

# %%
#to find best k value
scoreList = []
for i in range(1,20):
    knn2 = KNeighborsClassifier(n_neighbors = i)  
    knn2.fit(X_train, y_train)
    scoreList.append(knn2.score(X_test, y_test))
    
plt.plot(range(1,20), scoreList)
plt.xticks(np.arange(1,20,1))
plt.xlabel("K value")
plt.ylabel("Score")
plt.show()

# %%
from sklearn.svm import SVC, LinearSVC
svc = SVC()
svc.fit(X_train, y_train)

accuracy = accuracy_score(y_test, svc.predict(X_test))
accuracy_rounded = round(accuracy*100,2)

accuracies['Support Vector Machines(SVC)'] = accuracy_rounded

print(color.BOLD + "Accuracy of Support Vector Machines(SVC) is ", accuracy_rounded,'%')
# Out:
# Accuracy of Support Vector Machines(SVC) is  46.52 %

# %%
from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()
GNB.fit(X_train, y_train)

accuracy = accuracy_score(y_test, GNB.predict(X_test))
accuracy_rounded = round(accuracy*100,2)

accuracies['Naive Bayes'] = accuracy_rounded

print(color.BOLD + "Accuracy of Naive Bayes is ", accuracy_rounded,'%')
# Out:
# Accuracy of Naive Bayes is  94.35 %

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)

accuracy = accuracy_score(y_test, decision_tree.predict(X_test))
accuracy_rounded = round(accuracy*100,2)

accuracies['Decision Tree'] = accuracy_rounded

print(color.BOLD + "Accuracy of Decision Tree is ", accuracy_rounded,'%')
# Out:
# Accuracy of Decision Tree is  92.32 %

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)

model_accuracy = accuracy_score(y_test, classifier.predict(X_test))
accuracy_rounded = round(model_accuracy*100,2)

accuracies['Random Forest'] = accuracy_rounded

print(color.BOLD + "Accuracy of Random Forest is ", accuracy_rounded,'%')
# Out:
# Accuracy of Random Forest is  95.94 %

# %%
#Accuracies for all the models
accuracies
# Out:
# {'Logistic Regression': 94.35,
#  'K-Nearest Neighbors': 60.0,
#  'Support Vector Machines(SVC)': 46.52,
#  'Naive Bayes': 94.35,
#  'Decision Tree': 92.32,
#  'Random Forest': 95.94}

# %%
#Exporting model using joblib library
import joblib
joblib.dump(logreg,"hdp_modelss.pkl")
# Out:
# ['hdp_modelss.pkl']
